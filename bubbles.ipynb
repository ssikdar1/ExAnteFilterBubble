# %%
import random

# number of goods
N = 1000

# number of goods to select in the simulation
# T << N
T = 100

# init the utilities
u = [1 for i in range(N)]

# p ∈ (0, 1) 
p = [random.uniform(0,1) for i in range(N)]

# To keep track of what goods we chosen so far
items = [i for i in range(N)]

selections = []

# δ ∈ (0, 1) strength of learning spillovers
delta = .1

# d d(i, j) represents the distance that good j is from the consumed item i.
# so min number of hops on the circle
def d(i,j):
    return min(abs(i-j), abs(i-j-N))

# update
def update(i,j):
    rt = u[i]
    delta_d_ij = delta**d(i,j)
    
    p[j] = (1-delta_d_ij)* p[j] + delta_d_ij * rt

for t in range(T):
    print("iterations: %d" % t)
    if i == 0:
        # for the first iteration choose item N/2 
        idx = N//2
    else:
        # after look for highest probability, skip over previously selected nodes
        val, idx = max((val, idx) for (idx, val) in enumerate(p)if idx not in selections )
    
    choice = items[idx]
    selections.append(choice)
    print("chose item: %s " % (choice))
    
    # update beliefs
    for p_idx in range(len(p)):
        update(idx, p_idx)
# Out:
# iterations: 0
# chose item: 72
# iterations: 1
# chose item: 279
# iterations: 2
# chose item: 256
# iterations: 3
# chose item: 99
# iterations: 4
# chose item: 955
# iterations: 5
# chose item: 907
# iterations: 6
# chose item: 153
# iterations: 7
# chose item: 815
# iterations: 8
# chose item: 345
# iterations: 9
# chose item: 387
# iterations: 10
# chose item: 58
# iterations: 11
# chose item: 702
# iterations: 12
# chose item: 351
# iterations: 13
# chose item: 444
# iterations: 14
# chose item: 663
# iterations: 15
# chose item: 707
# iterations: 16
# chose item: 824
# iterations: 17
# chose item: 28
# iterations: 18
# chose item: 832
# iterations: 19
# chose item: 857
# iterations: 20
# chose item: 809
# iterations: 21
# chose item: 963
# iterations: 22
# chose item: 508
# iterations: 23
# chose item: 559
# iterations: 24
# chose item: 515
# iterations: 25
# chose item: 780
# iterations: 26
# chose item: 882
# iterations: 27
# chose item: 782
# iterations: 28
# chose item: 36
# iterations: 29
# chose item: 212
# iterations: 30
# chose item: 808
# iterations: 31
# chose item: 413
# iterations: 32
# chose item: 575
# iterations: 33
# chose item: 722
# iterations: 34
# chose item: 457
# iterations: 35
# chose item: 170
# iterations: 36
# chose item: 22
# iterations: 37
# chose item: 293
# iterations: 38
# chose item: 784
# iterations: 39
# chose item: 0
# iterations: 40
# chose item: 305
# iterations: 41
# chose item: 432
# iterations: 42
# chose item: 569
# iterations: 43
# chose item: 842
# iterations: 44
# chose item: 489
# iterations: 45
# chose item: 908
# iterations: 46
# chose item: 431
# iterations: 47
# chose item: 577
# iterations: 48
# chose item: 24
# iterations: 49
# chose item: 33
# iterations: 50
# chose item: 888
# iterations: 51
# chose item: 911
# iterations: 52
# chose item: 532
# iterations: 53
# chose item: 344
# iterations: 54
# chose item: 910
# iterations: 55
# chose item: 667
# iterations: 56
# chose item: 354
# iterations: 57
# chose item: 867
# iterations: 58
# chose item: 499
# iterations: 59
# chose item: 30
# iterations: 60
# chose item: 469
# iterations: 61
# chose item: 102
# iterations: 62
# chose item: 710
# iterations: 63
# chose item: 517
# iterations: 64
# chose item: 595
# iterations: 65
# chose item: 71
# iterations: 66
# chose item: 551
# iterations: 67
# chose item: 59
# iterations: 68
# chose item: 462
# iterations: 69
# chose item: 681
# iterations: 70
# chose item: 821
# iterations: 71
# chose item: 421
# iterations: 72
# chose item: 766
# iterations: 73
# chose item: 498
# iterations: 74
# chose item: 16
# iterations: 75
# chose item: 855
# iterations: 76
# chose item: 433
# iterations: 77
# chose item: 871
# iterations: 78
# chose item: 626
# iterations: 79
# chose item: 420
# iterations: 80
# chose item: 948
# iterations: 81
# chose item: 366
# iterations: 82
# chose item: 38
# iterations: 83
# chose item: 198
# iterations: 84
# chose item: 162
# iterations: 85
# chose item: 818
# iterations: 86
# chose item: 416
# iterations: 87
# chose item: 14
# iterations: 88
# chose item: 628
# iterations: 89
# chose item: 49
# iterations: 90
# chose item: 437
# iterations: 91
# chose item: 819
# iterations: 92
# chose item: 17
# iterations: 93
# chose item: 673
# iterations: 94
# chose item: 406
# iterations: 95
# chose item: 883
# iterations: 96
# chose item: 915
# iterations: 97
# chose item: 418
# iterations: 98
# chose item: 954
# iterations: 99
# chose item: 382

# %%
print(sorted(selections))
# Out:
# [0, 14, 16, 17, 22, 24, 28, 30, 33, 36, 38, 49, 58, 59, 71, 72, 99, 102, 153, 162, 170, 198, 212, 256, 279, 293, 305, 344, 345, 351, 354, 366, 382, 387, 406, 413, 416, 418, 420, 421, 431, 432, 433, 437, 444, 457, 462, 469, 489, 498, 499, 508, 515, 517, 532, 551, 559, 569, 575, 577, 595, 626, 628, 663, 667, 673, 681, 702, 707, 710, 722, 766, 780, 782, 784, 808, 809, 815, 818, 819, 821, 824, 832, 842, 855, 857, 867, 871, 882, 883, 888, 907, 908, 910, 911, 915, 948, 954, 955, 963]

# %%
d(20,1)
d(20,2)
d(19,20)
d(18,2)
d(8,12)
